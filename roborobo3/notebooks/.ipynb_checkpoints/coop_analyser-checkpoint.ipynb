# %%
# %load_ext Cython
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.set_palette('colorblind')

# %%
elems = ['mlp_nosee', 'mlp_see', 'elman_nosee', 'elman_see']

# %%
out = []

for elem in elems:
    logdir = '../logs/{}_partner/'.format(elem)
    data = pd.read_csv(logdir + 'observer.txt', delimiter='\t')
    data['onValueObj'] = data['onOpp'] * data['coop']
    data['onNonValueObj'] = data['onOpp'] * (1 - data['coop'])
    data['exploring'] = 1 - data['onOpp']
    cur_gen = data.query("gen == 1999 and iter  > 00")
    cur_gen.groupby('ind').mean()[['onValueObj', 'onNonValueObj', 'exploring']]
    vals = cur_gen.groupby('ind').mean()[['onValueObj', 'onNonValueObj', 'exploring']]
    for dummy, val in vals.iterrows():
        out.append({
            'group': elem,
            'ind': dummy,
            'status': 'onActiveObj',
            'time': val['onValueObj']
        })
        out.append({
            'group': elem,
            'ind': dummy,
            'status': 'onInactiveObj',
            'time': val['onNonValueObj']
        })
        out.append({
            'group': elem,
            'ind': dummy,
            'status': 'exploring',
            'time': val['exploring']
        })
data = pd.DataFrame(out)

# %%
sns.factorplot(kind="violin", cut=0, x="status", y="time", col="group", inner="stick", data=data, size=4, facet_kws={'ylim': [0, 1]}, bw=0.2
        )

# %%
data.query('status == "onActiveObj"').groupby('group').max()['time']
# Out:
# group
# elman_nosee    0.489870
# elman_see      0.725738
# mlp_nosee      0.810405
# mlp_see        0.674087
# Name: time, dtype: float64

# %%
data.query('group == "elman_nosee" and ind == 8')
# Out:
#            group  ind         status     time
# 324  elman_nosee    8    onActiveObj  0.69575
# 325  elman_nosee    8  onInactiveObj  0.05375
# 326  elman_nosee    8      exploring  0.25050

# %%
data = pd.read_csv("../logs/mlp_nosee_partner/analysis_log.txt", delimiter="\t")

# %%
cur_gen = data.query("generation == 1999")
cur_gen
# Out:
#        generation  ind  rank  coop  rep      it  onOpp
# 22500        1999   34    50     0    0  0.6180    NaN
# 22501        1999   34    50     0    1  0.5835    NaN
# 22502        1999   34    50     0    2  0.5085    NaN
# 22503        1999   34    50     0    3  0.4440    NaN
# 22504        1999   34    50     0    4  0.8150    NaN
# 22505        1999   34    50     0    5  0.7160    NaN
# 22506        1999   34    50     0    6  0.0680    NaN
# 22507        1999   34    50     0    7  0.6750    NaN
# 22508        1999   34    50     0    8  0.8125    NaN
# 22509        1999   34    50     0    9  0.7115    NaN
# 22510        1999   34    50     0   10  0.6470    NaN
# 22511        1999   34    50     0   11  0.1635    NaN
# 22512        1999   34    50     0   12  0.5385    NaN
# 22513        1999   34    50     0   13  0.6070    NaN
# 22514        1999   34    50     0   14  0.5180    NaN
# 22515        1999   34    50     0   15  0.6620    NaN
# 22516        1999   34    50     0   16  0.3595    NaN
# 22517        1999   34    50     0   17  0.5880    NaN
# 22518        1999   34    50     0   18  0.6225    NaN
# 22519        1999   34    50     0   19  0.3885    NaN
# 22520        1999   34    50     0   20  0.9600    NaN
# 22521        1999   34    50     0   21  0.6125    NaN
# 22522        1999   34    50     0   22  0.0000    NaN
# 22523        1999   34    50     0   23  0.7035    NaN
# 22524        1999   34    50     0   24  0.4500    NaN
# 22525        1999   34    50     1    0  0.8070    NaN
# 22526        1999   34    50     1    1  0.5445    NaN
# 22527        1999   34    50     1    2  0.5070    NaN
# 22528        1999   34    50     1    3  0.7590    NaN
# 22529        1999   34    50     1    4  0.4505    NaN
# ...           ...  ...   ...   ...  ...     ...    ...
# 24719        1999   22     6     0   19  0.6420    NaN
# 24720        1999   22     6     0   20  0.6375    NaN
# 24721        1999   22     6     0   21  0.7080    NaN
# 24722        1999   22     6     0   22  0.3185    NaN
# 24723        1999   22     6     0   23  0.4925    NaN
# 24724        1999   22     6     0   24  0.6335    NaN
# 24725        1999   22     6     1    0  0.5760    NaN
# 24726        1999   22     6     1    1  0.6225    NaN
# 24727        1999   22     6     1    2  0.3575    NaN
# 24728        1999   22     6     1    3  0.6215    NaN
# 24729        1999   22     6     1    4  0.5690    NaN
# 24730        1999   22     6     1    5  0.7790    NaN
# 24731        1999   22     6     1    6  0.6860    NaN
# 24732        1999   22     6     1    7  0.2360    NaN
# 24733        1999   22     6     1    8  0.5315    NaN
# 24734        1999   22     6     1    9  0.4655    NaN
# 24735        1999   22     6     1   10  0.6060    NaN
# 24736        1999   22     6     1   11  0.0000    NaN
# 24737        1999   22     6     1   12  0.0020    NaN
# 24738        1999   22     6     1   13  0.7295    NaN
# 24739        1999   22     6     1   14  0.0965    NaN
# 24740        1999   22     6     1   15  0.5535    NaN
# 24741        1999   22     6     1   16  0.0000    NaN
# 24742        1999   22     6     1   17  0.4725    NaN
# 24743        1999   22     6     1   18  0.2175    NaN
# 24744        1999   22     6     1   19  0.5830    NaN
# 24745        1999   22     6     1   20  0.5985    NaN
# 24746        1999   22     6     1   21  0.0300    NaN
# 24747        1999   22     6     1   22  0.6420    NaN
# 24748        1999   22     6     1   23  0.1860    NaN
#
# [2249 rows x 7 columns]

# %%
s = cur_gen.diff()['onOpp']
cur_gen['enterOpp'] = s
# Out:
# /home/paul/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
entrance = cur_gen.query('enterOpp == 1').groupby(('coop', 'ind'), as_index=False).sum()
entrance['enterOpp'] /= 25
sns.violinplot(data=entrance, x='coop', y='enterOpp', inner='stick', bw=0.2, cut=0)
plt.title("Nombre d'entrées sur une opportunité de cooperation moyen par individu (sur 4000 itérations × 25 réplications)")
plt.ylim((0, 100))
# Out:
# (0, 100)

# %%
av_on_coop = cur_gen.groupby(('ind', 'coop'), as_index=False)['onOpp'].mean()
sns.violinplot(data=av_on_coop, x='coop', y='onOpp', inner='stick', bw=0.2, cut=0)
plt.title('% Temps passé sur une opportunité de coopération (sur 4000 itérations × 25 réplications)')
plt.ylim((0, 1))
# Out:
# (0, 1)

# %%
av_time_on_opp = cur_gen.groupby(('ind', 'rep', 'coop'), as_index=False)['onOpp'].apply(sequence_size_mean).to_frame("average_time")
av_time_on_opp.reset_index(inplace=True)
av_time_on_opp = av_time_on_opp.groupby(('ind', 'coop'), as_index=False).mean()

# %%
# %%cython
# cimport cython
# cimport numpy as np
# import numpy as np
#
# @cython.boundscheck(False)
# @cython.wraparound(False)
# def list_of_sequence_size(np.ndarray a):
#     cdef int start = -1
#     cdef int i
#     out = []
#     for i in range(len(a)):
#         if start == -1 and a[i] == 1:
#             start = i
#         if start != -1 and a[i] == 0:
#             out.append(i - start)
#             start = -1
#     if start != -1:
#         out.append(len(a) - start)
#     return out
#
# def sequence_size(a):
#     return list_of_sequence_size(a.values)
#
# def sequence_size_mean(a):
#     elems = sequence_size(a)
#     if elems:
#         return np.mean(elems)
#     else:
#         return np.NaN

# %%
sns.violinplot(data=av_time_on_opp, y='average_time', x='coop', inner='stick', bw=0.2, cut=0)
plt.title('Temps moyen passé sur une opportunité avant d\'en sortir par individu (sur 4000 itérations × 25 réplications)')
plt.ylim((0, 250))
# Out:
# (0, 250)

# %%
# Out:
# [3, 2]
