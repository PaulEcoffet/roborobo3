# %%
# %load_ext Cython
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.set_palette('colorblind')

# %%
folder = "../logs/partner_control_new_func_cma/"
fit = pd.read_csv(folder + "fitnesslog.txt", delimiter="\t")

# %%
fit[['medfit', 'maxfit', 'minfit']].plot()
plt.title('Évolution de la fitness au cours de {} générations'.format(fit['gen'].max()))
# Out:
# Text(0.5,1,'Évolution de la fitness au cours de 5819 générations')

# %%
data = pd.read_csv(folder+"/analysis_log.txt", delimiter="\t")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-fcb7fe67a3d7> in <module>()
# ----> 1 data = pd.read_csv(folder+"/analysis_log.txt", delimiter="\t")
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     644                     skip_blank_lines=skip_blank_lines)
#     645
# --> 646         return _read(filepath_or_buffer, kwds)
#     647
#     648     parser_f.__name__ = name
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     387
#     388     # Create the parser.
# --> 389     parser = TextFileReader(filepath_or_buffer, **kwds)
#     390
#     391     if (nrows is not None) and (chunksize is not None):
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     728             self.options['has_index_names'] = kwds['has_index_names']
#     729
# --> 730         self._make_engine(self.engine)
#     731
#     732     def close(self):
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#     921     def _make_engine(self, engine='c'):
#     922         if engine == 'c':
# --> 923             self._engine = CParserWrapper(self.f, **self.options)
#     924         else:
#     925             if engine == 'python':
#
# ~/miniconda3/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1388         kwds['allow_leading_cols'] = self.index_col is not False
#    1389
# -> 1390         self._reader = _parser.TextReader(src, **kwds)
#    1391
#    1392         # XXX
#
# pandas/parser.pyx in pandas.parser.TextReader.__cinit__ (pandas/parser.c:4184)()
#
# pandas/parser.pyx in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:8449)()
#
# FileNotFoundError: File b'../logs/partner_control_gauss_cma//analysis_log.txt' does not exist

# %%
last_gen = data['generation'].max()
last_gen
# Out:
# 1999

# %%
dat = data.query('onOpp == 1 and generation == {}'.format(last_gen)).groupby(("ind", "coop"), as_index=False).mean()
dat
# Out:
#      ind      coop  generation  rank       rep          it  onOpp   ownCoop
# 0      0  0.000000      1999.0  27.0  7.471898  258.020850    1.0  0.137747
# 1      0  0.111111      1999.0  27.0  7.477388  258.211222    1.0  0.149343
# 2      0  0.222222      1999.0  27.0  7.555874  259.664885    1.0  0.116381
# 3      0  0.333333      1999.0  27.0  7.501757  258.985296    1.0  0.090653
# 4      0  0.444444      1999.0  27.0  7.508903  257.108129    1.0  0.081124
# 5      0  0.555556      1999.0  27.0  7.515285  258.154793    1.0  0.064677
# 6      0  0.666667      1999.0  27.0  7.532493  258.763972    1.0  0.043061
# 7      0  0.777778      1999.0  27.0  7.539113  259.407823    1.0  0.050222
# 8      0  0.888889      1999.0  27.0  7.470596  257.546853    1.0  0.028278
# 9      0  1.000000      1999.0  27.0  7.479591  258.219515    1.0  0.022807
# 10     1  0.000000      1999.0  46.0  7.497879  256.318083    1.0  0.205377
# 11     1  0.111111      1999.0  46.0  7.529303  261.627025    1.0  0.153273
# 12     1  0.222222      1999.0  46.0  7.517536  257.963893    1.0  0.115036
# 13     1  0.333333      1999.0  46.0  7.463475  259.650013    1.0  0.128369
# 14     1  0.444444      1999.0  46.0  7.541731  258.156687    1.0  0.078730
# 15     1  0.555556      1999.0  46.0  7.473855  259.069329    1.0  0.079296
# 16     1  0.666667      1999.0  46.0  7.529785  257.979668    1.0  0.058204
# 17     1  0.777778      1999.0  46.0  7.458387  258.333549    1.0  0.055375
# 496   49  0.666667      1999.0  45.0  7.538815  261.224616    1.0  0.069468
# 497   49  0.777778      1999.0  45.0  7.501032  257.054710    1.0  0.048708
# 498   49  0.888889      1999.0  45.0  7.474579  261.616834    1.0  0.047568
# 499   49  1.000000      1999.0  45.0  7.457695  256.632196    1.0  0.032356
#
# [500 rows x 8 columns]

# %%
def payoff_gauss(own, other):
    return np.exp(-np.power(own + other - 0.5, 2)/0.05);

def payoff_true(own, other):
    coeff = np.sqrt(2)
    return coeff * np.power(own + other, 0.5) - own
    
    
payoff = payoff_true
dat['reward'] = payoff(dat['ownCoop'], dat['coop'])
dat['totreward'] = payoff(dat['ownCoop'], dat['coop']) * 500

# %%
dat.query('rank == 1').sum() / 10 * 16
# Out:
# ind             544.000000
# coop              8.000000
# generation    31984.000000
# rank             16.000000
# rep             120.631388
# it             4141.249213
# onOpp            16.000000
# ownCoop           1.232465
# reward           15.391158
# totreward      7695.579244
# dtype: float64

# %%
sns.violinplot(data=dat, x='coop', y='reward', cut=0)

# %%
sns.tsplot(data=dat, time='coop', value='reward', unit="ind", err_style="unit_traces", estimator=np.nanmean)
plt.plot(np.linspace(0, 1, 1000), payoff(np.max((0.5-np.linspace(0, 1, 1000), np.zeros(1000)), 0), np.linspace(0, 1, 1000)), c='red', label='Récompense obtenue avec investissement optimal')
plt.ylim((0, 2))
plt.legend()
plt.ylabel('Récompense obtenue')
plt.xlabel('Investissement de l\'autre')

# %%
sns.tsplot(data=dat, time='coop', value='ownCoop', unit="ind", err_style="unit_traces", estimator=np.nanmean)
own = np.linspace(0, 1, 100)
other = np.outer(np.linspace(0, 1, 100),(np.ones(own.shape[0])))
best = np.argmax(payoff(own, other), axis=1)
plt.plot(own, own[best].T, c='red', label='propre investissement maximisant la récompense propre')
plt.ylim((-0.1, 1))
plt.legend()
plt.ylabel('Propre investissement')
plt.xlabel("Investissement de l'autre")

# %%
pal = sns.palettes.SEABORN_PALETTES['colorblind']
for i, y in enumerate((0.1, 0.3, 0.4)):
    x = np.linspace(0, 2, 1000)
    pay = np.exp(5 * payoff(x, y))
    plt.plot(x, pay, color=pal[i], label='$x_o$ = {}'.format(y))
    pay_max = np.max(pay)
    bound = pay_max * 0.90
    i_ok = np.where(pay > bound)[0]
    xmin = x[i_ok[0]]
    xmax = x[i_ok[-1]]
    plt.axvspan(xmin, xmax, alpha=0.3, color=pal[i], label="$x$ pour $P(x) > 95\% P_{max}$")
plt.legend()
plt.title('Payoff en fonction de l\'investissement propre ($P(x_s, x_o)$)')
plt.xlabel('Propre investissement $x_s$')
plt.ylabel('Gain propre ($P(x_s, x_o)$)')

# %%
dat
# Out:
#      ind      coop  generation  rank       rep          it  onOpp   ownCoop  \
# 0      0  0.000000      1499.0  12.0  7.479129  258.343272    1.0  0.200239
# 1      0  0.111111      1499.0  12.0  7.521139  256.956432    1.0  0.212032
# 2      0  0.222222      1499.0  12.0  7.461874  256.011553    1.0  0.159386
# 3      0  0.333333      1499.0  12.0  7.514441  258.081725    1.0  0.143091
